# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import csv
# Out:
# <frozen importlib._bootstrap>:241: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
#>>>RUN: L1.0-runcell02

#set plot resolution
# %config InlineBackend.figure_format = 'retina'

#set default figure parameters
plt.rcParams['figure.figsize'] = (9,6)

medium_size = 12
large_size = 15

plt.rc('font', size=medium_size)          # default text sizes
plt.rc('xtick', labelsize=medium_size)    # xtick labels
plt.rc('ytick', labelsize=medium_size)    # ytick labels
plt.rc('legend', fontsize=medium_size)    # legend
plt.rc('axes', titlesize=large_size)      # axes title
plt.rc('axes', labelsize=large_size)      # x and y labels
plt.rc('figure', titlesize=large_size)    # figure title

# %%
x = np.linspace(start=-4, stop=4, num=5)
y = np.sin(x)

# %%
plt.plot(x, y, label='sin')
plt.show()

# %%
x = np.linspace(start=-4, stop=4, num=100)
#Evaluar los datos usando la distribucion normal
mu = 0
std = 1
y = stats.norm.pdf(x,mu,std)

plt.plot(x,np.sin(x), label='sin')
plt.plot(x,np.cos(x), label='cos')
plt.plot(x, y, label='normal distribution')

#Stily
plt.title('Simple plot of common functions', fontsize=15)
plt.legend(loc='lower right', fontsize=15)
plt.xlabel('x', fontsize=15)
plt.ylabel('y', fontsize=15)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.grid()
plt.show()

# %%
#>>>EXERCISE: L1.1.1
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    e_x = pow(2.718281828459045,x)
    return e_x


if exp_func(1) == 2.718281828459045:
    print('correct')
else:
    print('incorrect')
# Out:
# correct

# %%
def plot1(x):

    plt.plot(x, exp_func(x))

    #labels
    plt.xlabel('x', fontsize=15)
    plt.ylabel('y', fontsize=15)

    #ticks
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)

    plt.show()

def plot2(x):
    plt.plot(x, exp_func(x), label='exp(x)')
    
    #labels
    plt.title('Exponential Function', fontsize=15)
    plt.legend(loc='lower right', fontsize=12)
    plt.xlabel('x', fontsize=15)
    plt.ylabel('exp(x)', fontsize=15)
    
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    
    #grid
    plt.grid()
    plt.show()
    
    
def plot3(x):
    
    plt.plot(x, exp_func(x), label='exp(x)')
    
    #estilo de etiquetas
    plt.title('Exponencial Function', fontsize=5)
    plt.legend(loc='lower right', fontsize=8)
    plt.xlabel('x', fontsize=8)
    plt.ylabel('exp(x)', fontsize=8)
    
    plt.xticks(fontsize=8)
    plt.yticks(fontsize=8)
    
    plt.grid()
    plt.show()

# %%
x = np.linspace(start=0, stop=10, num=100)
plot1(x)
plot2(x)
plot3(x)

# %% [markdown]
# ## Histogramas

# %%
#Randonly choose 1000 events between 0 and 10
bkg = np.random.uniform(0,10,1000)

# %%
histy, bin_edges = np.histogram(bkg, bins=20)
bin_centers = 0.5*(bin_edges[1:] + bin_edges[:-1])

#ejes
fig, ax = plt.subplots(figsize=(9,6))

#Grafica
plt.plot(bin_centers,histy, drawstyle= 'steps-mid')
plt.ylim(0,100)
ax.set_ylim([0,100])

#Ajustar estilo de las etiquetas
plt.xlabel('x',fontsize=15)
plt.ylabel('N_samples',fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
#'steps-mind' is not a valid value for drawstyle; 
#supported values are 'default', 'steps-mid', 
#'steps-pre', 'steps-post', 'steps'

# %%
histy
# Out:
# array([31, 46, 47, 54, 45, 59, 56, 45, 52, 39, 38, 58, 44, 49, 55, 49, 58,
#        50, 68, 57])

# %%
#>>>EXERCISE: L1.2.1
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

#Randomly choose 1000 events between 0 and 10
bkg = np.random.uniform(0,10, 1000) 
histy, bin_edges = np.histogram(bkg, bins=20)

integral = 0 #complete the code
integral= sum(histy[i] * bin_centers[i]*2 for i in range(len(histy)))

print("Integral:",integral)
# Out:
# Integral: 10034.482210659966

# %%
print(len(bin_centers),len(histy))
# Out:
# 20 20

# %%
#>>>EXERCISE: L1.2.2
#Randomly choose 1000 events between 0 and 10, with set RNG seed
np.random.seed(0) # makes the random numbers stay the same between runs
samples = np.random.uniform(0, 10, 1000) 

# Below, write code to make a histogram, and try with 3, 10, and 1000 bins
#primera con 3 bins
histy1, bins1 = np.histogram(samples, bins=3)
bins_c1 = 0.5 * (bins1[1:] + bins1[:-1])
#Con 10 bins
histy2, bins2 = np.histogram(samples, bins=10)
bins_c2 = 0.5 * (bins2[1:] + bins2[:-1])
#Con 100 bins
histy3, bins3 = np.histogram(samples, bins=100)
bins_c3 = 0.5 * (bins3[1:] + bins3[:-1])

#Ejes
fig, (ax1,ax2,ax3) = plt.subplots(3, 1, figsize=(12,6))

#Primera grafica
ax1.hist(bins_c1, bins1, weights= histy1)
ax1.set_title('tres bins', fontsize=10)
#Segunda grafica
ax2.hist(bins_c2, bins2, weights= histy2)
ax2.set_title('10 bins', fontsize=10)
#Tercera grafica
ax3.hist(bins_c3, bins3, weights= histy3)
ax3.set_title('100 bins', fontsize=10)
# Out:
# Text(0.5, 1.0, '100 bins')

# %%
bkg = np.random.uniform(0,5,1000)
histy4,bins4 = np.histogram(bkg, bins=11)
plt.hist(bkg, 11)
plt.show()

# %%
#>>>RUN: L1.2-slides

from IPython.display import IFrame

IFrame(src='https://mitx-8s50.github.io/slides/L01/slides1.html', width=975, height=550)
# Out:
#         <iframe
#             width="975"
#             height="550"
#             src="https://mitx-8s50.github.io/slides/L01/slides1.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#>>>RUN: L1.3-runcell01

#Let's sample a uniform distribution 10k times each
bkg1 = np.random.uniform(0,10, 10000)
bkg2 = np.random.uniform(0,10, 10000) #this outputs an array of 10,000

#Now we sum them
data = bkg1 + bkg2 #since bkg1 and 2 are numpy arrays, doing this adds element-wise (called "broadcasting")


def getHist(data):
    """Get hist y values, bin edges, and bin centers as np arrays"""
    histy, bin_edges = np.histogram(data, bins=100)
    bin_centers = 0.5*(bin_edges[1:] + bin_edges[:-1])
    return (histy, bin_edges, bin_centers)

def plotData(data):
    #plotting-------------------
    #plot size
    #fig, ax = plt.subplots(figsize=(9,6)) #optionally set the figure size here
    
    #plot data
    histy, bin_edges, bin_centers = getHist(data)
    plt.plot(bin_centers,histy,drawstyle = 'steps-mid')
    
    #plot labels and style
    plt.xlabel('x', fontsize=15) #Label x
    plt.ylabel('N samples', fontsize=15) #Label y
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.show()

def plotDataNormalized(data):
    histy, bin_edges, bin_centers = getHist(data)
    # normalize the hist y values to the total number of samples (integral)
    integral = len(data)
    norm_histy = histy / integral # again, division is broadcast to elements of histy
    plt.plot(bin_centers,norm_histy,drawstyle = 'steps-mid')
    plt.xlabel('x', fontsize=15) #Label x
    plt.ylabel('Relative probability', fontsize=15) #Label y
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.show()

plotData(data)
plotDataNormalized(data)
